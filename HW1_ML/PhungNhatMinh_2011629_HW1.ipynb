# %% [markdown]
# # **Báo cáo homework 1**

# %% [markdown]
# ## **1. Logistic regression sử dụng thư viện numpy**

# %%
# %run logistic_np.py
# Out:
# Reading vehicle data...
# EOF Reached
# Done reading
#
# Shape of tran_x and test_x after run reshape2D method
# train_xs shape: (2400, 4096)
# test_xs shape: (600, 4096)
#
# Shape of tran_x and test_x after run add_one method
# train_xs shape: (2400, 4097)
# test_xs shape: (600, 4097)
# Epoch 1000: loss is 0.25061
# TP = 262
# FP = 84
# P = 300.0
# Precision: 0.757
# Recall: 0.873
# F1-score: 0.811

# %% [markdown]
# ## **2. Logistic regression sử dụng thư viện tensorflow**

# %%
# %run logistic_tf.py
# Out:
# Reading vehicle data...
# EOF Reached
# Done reading
# loss: 0.13052400946617126
# Epoch 1000: loss is 0.13052
# TP = 249
# FP = 78
# P = 300.0
# Precision: 0.761
# Recall: 0.830
# F1-score: 0.794
# [[-0.19223608]
#  [ 0.02748697]
#  [ 0.01306745]
#  ...
#  [-0.02838001]
#  [-0.01942124]
#  [ 0.00276815]]

# %% [markdown]
# ## **3. Softmax regression sử dụng thư viện numpy**

# %%
# %run softmax_np.py
# Out:
# Reading fashion MNIST data...
# <class 'numpy.ndarray'>
# Done reading
# Confusion matrix:
# [[0.95 0.   0.   0.03 0.   0.   0.04 0.   0.   0.  ]
#  [0.   0.91 0.   0.12 0.   0.   0.   0.   0.   0.  ]
#  [0.04 0.   0.54 0.05 0.26 0.   0.11 0.   0.   0.  ]
#  [0.07 0.02 0.   0.82 0.02 0.   0.02 0.   0.   0.  ]
#  [0.   0.   0.11 0.05 0.74 0.   0.08 0.   0.   0.  ]
#  [0.   0.   0.   0.   0.   0.89 0.   0.1  0.02 0.  ]
#  [0.24 0.   0.09 0.03 0.21 0.02 0.45 0.   0.02 0.  ]
#  [0.   0.   0.   0.   0.   0.06 0.   0.82 0.   0.12]
#  [0.   0.   0.   0.03 0.   0.04 0.   0.02 0.93 0.  ]
#  [0.   0.   0.   0.   0.   0.02 0.   0.02 0.   0.96]]
# Diagonal values:
# [0.95 0.91 0.54 0.82 0.74 0.89 0.45 0.82 0.93 0.96]

# %% [markdown]
# ## **4. Softmax regression sử dụng thư viện tensorflow**

# %%
# %run softmax_tf.py
# Out:
# Reading fashion MNIST data...
# <class 'numpy.ndarray'>
# Done reading
# Confusion matrix:
# [[0.95 0.   0.   0.03 0.   0.   0.04 0.   0.   0.  ]
#  [0.   0.91 0.   0.12 0.   0.   0.   0.   0.   0.  ]
#  [0.04 0.   0.54 0.05 0.26 0.   0.11 0.   0.   0.  ]
#  [0.07 0.02 0.   0.82 0.02 0.   0.02 0.   0.   0.  ]
#  [0.   0.   0.11 0.05 0.74 0.   0.08 0.   0.   0.  ]
#  [0.   0.   0.   0.   0.   0.89 0.   0.1  0.02 0.  ]
#  [0.24 0.   0.09 0.03 0.21 0.02 0.45 0.   0.02 0.  ]
#  [0.   0.   0.   0.   0.   0.06 0.   0.82 0.   0.12]
#  [0.   0.   0.   0.03 0.   0.04 0.   0.02 0.93 0.  ]
#  [0.   0.   0.   0.   0.   0.02 0.   0.02 0.   0.96]]
# Diagonal values:
# [0.95 0.91 0.54 0.82 0.74 0.89 0.45 0.82 0.93 0.96]
