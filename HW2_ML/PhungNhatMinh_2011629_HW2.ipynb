# %% [markdown]
# # **Báo cáo homework 2**

# %% [markdown]
# ## **1. Bài toán phân loại tập dữ liệu bat 3 lớp.**

# %% [markdown]
# **Đề bài:** Cho tập dữ liệu bat 3 lớp được gãn nhãn 0, 1, 2; gồm 12000 mẫu là tọa độ các điểm trên trục tọa độ 2D tạo thành hình logo batman. Tạo Neural Network mạng Fully Connected để phân loại các điểm dữ liệu trên bằng Numpy và Tensorflow.

# %% [markdown]
# ### **1.1. Sử dụng thư viện Numpy để giải quyết bài toán**

# %% [markdown]
# Ở phương pháp sử dụng thư viện numpy, ta chọn:
# - Số lần lặp (epoch) là 3000 lần.
# - Learning rate là 0.0005.
# - Dùng phương pháp mini-batch gradient descent với momentum có momentum rate là 0.9 để cập nhật giá trị w, batch size là 400.

# %%
# %run dnn_np.py
# Out:
# Reading bat data...
# EOF Reached
# Done reading
# Epoch 50: loss is 1.01799, learning rate is 0.0005
# Epoch 100: loss is 0.98106, learning rate is 0.0005
# Epoch 150: loss is 0.94918, learning rate is 0.0005
# Epoch 200: loss is 0.93880, learning rate is 0.0005
# Epoch 250: loss is 0.90312, learning rate is 0.0005
# Epoch 300: loss is 0.81930, learning rate is 0.0005
# Epoch 350: loss is 0.66116, learning rate is 0.0005
# Epoch 400: loss is 0.59087, learning rate is 0.0005
# Epoch 450: loss is 0.56037, learning rate is 0.0005
# Epoch 500: loss is 0.48781, learning rate is 0.0005
# Epoch 550: loss is 0.46881, learning rate is 0.0005
# Epoch 600: loss is 0.42125, learning rate is 0.0005
# Epoch 650: loss is 0.37701, learning rate is 0.0005
# Epoch 700: loss is 0.38387, learning rate is 0.0005
# Epoch 750: loss is 0.34522, learning rate is 0.0005
# Epoch 800: loss is 0.33343, learning rate is 0.0005
# Epoch 850: loss is 0.35584, learning rate is 0.0005
# ...

# %% [markdown]
# ### **1.2. Sử dụng thư viện Tensorflow để giải quyết bài toán**

# %% [markdown]
# Ở phương pháp sử dụng thư viện tensorflow, ta chọn:
# - Số lần lặp (epoch) là 5000 lần.
# - Learning rate là 0.0005.
# - Dùng phương pháp mini-batch gradient descent với momentum có momentum rate là 0.005 để cập nhật giá trị w, batch size là 200.

# %%
# %run dnn_tf.py
# Out:
# Reading bat data...
# EOF Reached
# Done reading
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmppv_gyo3c
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmppv_gyo3c', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %% [markdown]
# ### **1.3. Kết luận**

# %% [markdown]
# - Khi sử dụng batch gradient descent, ta cần 10000 epochs để loss giảm được đến 0.2; còn khi sử dụng mini-batch gradient descent ta chỉ cần 3000 đến 5000 epochs đế khiến loss ổn định ở mức 0.12 => mini-batch gradient descent cho ra hiệu quả cao hơn.
# - Kết quả phân loại của cả 2 phương pháp dùng thư việ Numpy và Tensorflow đểu đạt độ chính xác trên 90%.

# %% [markdown]
# ## **2. Bài toán phân loại quần áo, phụ kiện.**

# %% [markdown]
# **Đề bài:** Cho tập dữ liệu MNIST bao gồm 70000 ảnh xám có kích thước 28x28, mỗi ảnh thuộc 1 trong 10 loại quần, áo, túi xách,... Trong đó có 50000 ảnh dùng để training, 10000 ảnh dùng để test, 10000 ảnh dùng kiểm định (validation). Xây dựng mô Neural Network mạng Fully Connected phân loại các ảnh thành 10 nhóm quân, áo, túi xách,... bằng thư viện Numpy và Tensorflow.

# %% [markdown]
# ### **2.1. Sử dụng thư viện Numpy để giải quyết bài toán**

# %% [markdown]
# Ở phương pháp sử dụng thư viện numpy, ta chọn:
# - Số lần lặp (epoch) là 1000 lần.
# - Learning rate là 0.0005.
# - Dùng phương pháp mini-batch gradient descent với momentum có momentum rate là 0.9 để cập nhật giá trị w, batch size là 500.

# %%
# %run dnn_np_mnist.py
# Out:
# Reading fashion MNIST data...
# Done reading
# Epoch 50: loss is 0.38702, learning rate is 0.0005
# Epoch 100: loss is 0.38822, learning rate is 0.0005
# Epoch 150: loss is 0.27891, learning rate is 0.0005
# Epoch 200: loss is 0.27998, learning rate is 0.0005
# Epoch 250: loss is 0.26913, learning rate is 0.0005
# Epoch 300: loss is 0.20071, learning rate is 0.0005
# Epoch 350: loss is 0.18242, learning rate is 0.0005
# Epoch 400: loss is 0.18819, learning rate is 0.0005
# Epoch 450: loss is 0.15699, learning rate is 0.0005
# Epoch 500: loss is 0.12095, learning rate is 0.0005
# Epoch 550: loss is 0.12678, learning rate is 0.0005
# Epoch 600: loss is 0.11429, learning rate is 0.0005
# Epoch 650: loss is 0.10850, learning rate is 0.0005
# Epoch 700: loss is 0.08094, learning rate is 0.0005
# Epoch 750: loss is 0.10017, learning rate is 0.0005
# Epoch 800: loss is 0.06408, learning rate is 0.0005
# Epoch 850: loss is 0.06890, learning rate is 0.0005
# ...

# %% [markdown]
# ### **2.2. Sử dụng thư viện Tensorflow để giải quyết bài toán**

# %% [markdown]
# Ở phương pháp sử dụng thư viện numpy, ta chọn:
# - Số lần lặp (epoch) là 1000 lần.
# - Learning rate là 0.0005.
# - Dùng phương pháp mini-batch gradient descent với momentum có momentum rate là 0.005 để cập nhật giá trị w, batch size là 500.

# %%
# %run dnn_tf_mnist.py
# Out:
# Reading fashion MNIST data...
# Done reading
# (50000, 784)
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp7nquq7a9
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp7nquq7a9', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %% [markdown]
# ### **2.3. Kết luận:**

# %% [markdown]
# Cả 2 phương pháp đều cho ra kết quả với độ chính xác đa phần là 90%, tỉ lệ chính xác cao hơn so với sử dụng softmax regression ở bài tập lớn 1.
